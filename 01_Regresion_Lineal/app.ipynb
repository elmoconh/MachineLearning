# %%
# %pip install pandas seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 931.4 kB/s eta 0:00:00 kB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.9/245.9 kB 2.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#   Using cached kiwisolver-1.4.5-cp311-cp311-macosx_11_0_arm64.whl (66 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 3.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 3.9 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

datos = pd.read_csv('datos.csv')

# %%
datos.head()
# Out:
#    celsius  fahrenheit
# 0      -40         -40
# 1      -10          14
# 2        0          32
# 3        8          46
# 4       15          59

# %%
if 'fahrenheit' in datos.columns:
    sns.scatterplot(x='celsius', y='fahrenheit', data=datos, hue='celsius', palette='coolwarm')
else:
    print("Column 'fahrenheit' does not exist in the dataframe.")

# %%
#Características (X), etiquetas (y)
x =datos["celsius"]
y = datos["fahrenheit"]

# %%
#transformamos los datos a un array de 2D
x_procesada = x.values.reshape(-1,1)
y_procesada = y.values.reshape(-1,1)
# esto se hace para que los datos sean compatibles con el modelo de regresión lineal

# %%
x_procesada
# Out:
# array([[-40],
#        [-10],
#        [  0],
#        [  8],
#        [ 15],
#        [ 22],
#        [ 38]])

# %%
# %pip install scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 3.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 4.0 MB/s eta 0:00:004.3 MB/s eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
#entrenamos el modelo
model.fit(x_procesada, y_procesada)
# Out:
# LinearRegression()

# %%
model.predict([[123]])
# Out:
# array([[252.41382453]])
